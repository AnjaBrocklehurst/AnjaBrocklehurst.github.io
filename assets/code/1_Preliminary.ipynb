# %% [markdown]
# # Preliminary graphs

# %%
#Import pandas, files and look at the data (show first two rown and ask for info)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set pandas display options to show all columns for .head command
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)       # Auto-detect the display width
pd.set_option('display.max_colwidth', None) # Show full content of each column

# Loading the datasets
file_path1 = r'ByCompany.csv'
Company_data = pd.read_csv(file_path1, sep=';')

file_path2 = r'ByTargets.csv'
Target_data = pd.read_csv(file_path2, sep=';')

# %%
Company_data.head(2)
# Out:
#     sbti_id         company_name organization_type                   location  \
# 0  40009754  AcBel Polytech Inc.         Corporate  Taiwan, Province of China
# 1  40008140       Chalhoub Group         Corporate       United Arab Emirates
#
#   region                             sector near_term_status  \
# 0   Asia  Technology Hardware and Equipment      Targets set
# 1   MENA                          Retailing      Targets set
#
#   near_term_target_classification near_term_target_year long_term_status  \
# 0                           1.5°C                  2030              NaN
# 1                           1.5°C                  2032              NaN
#
#   long_term_target_classification long_term_target_year  net_zero_status  \
# 0                             NaN                   NaN              NaN
# 1                             NaN                   NaN        Committed
#
#   net_zero_year reason_for_extension_or_removal date_updated  Unnamed: 16  \
# ...

# %%
# Assuming Company_data is already loaded
# Count occurrences of each sector
sector_counts = Company_data['sector'].value_counts().reset_index()
sector_counts.columns = ['sector', 'count']

# Create the barplot
plt.figure(figsize=(10, 6))
sns.barplot(data=sector_counts, x='sector', y='count', palette='viridis')

# Customize the plot
plt.title('Count of Occurrences by Sector', fontsize=16)
plt.xlabel('Sector', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\gfjgu\AppData\Local\Temp\ipykernel_13616\4183341043.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sector_counts, x='sector', y='count', palette='viridis')
# C:\Users\gfjgu\AppData\Local\Temp\ipykernel_13616\4183341043.py:15: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
